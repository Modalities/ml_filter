# %%
from ml_filter.training.embedding_training_pipeline import run_embedding_head_training_pipeline
from pathlib import Path
config_file_path = "data/configs/regressor/train_regression_head_200_de_config.yaml"
run_embedding_head_training_pipeline(Path(config_file_path))
# Out:
# INFO — Loading configuration from data/configs/regressor/train_regression_head_200_de_config.yaml
# INFO — Setting random seed: 42
# ...
